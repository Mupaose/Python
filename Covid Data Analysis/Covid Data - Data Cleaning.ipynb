# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import plotly as py
# %matplotlib inline
sns.set_style("darkgrid")

# %%
# importing the dataset
covid_df = pd.read_csv("covid_data.csv")

# %%
covid_df
# Out:
#        iso_code continent     location        date  total_cases  new_cases  \
# 0           AFG      Asia  Afghanistan  2020-01-03          NaN        0.0
# 1           AFG      Asia  Afghanistan  2020-01-04          NaN        0.0
# 2           AFG      Asia  Afghanistan  2020-01-05          NaN        0.0
# 3           AFG      Asia  Afghanistan  2020-01-06          NaN        0.0
# 4           AFG      Asia  Afghanistan  2020-01-07          NaN        0.0
# ...         ...       ...          ...         ...          ...        ...
# 297147      ZWE    Africa     Zimbabwe  2023-03-17     264391.0        0.0
# 297148      ZWE    Africa     Zimbabwe  2023-03-18     264391.0        0.0
# 297149      ZWE    Africa     Zimbabwe  2023-03-19     264391.0        0.0
# 297150      ZWE    Africa     Zimbabwe  2023-03-20     264391.0        0.0
# 297151      ZWE    Africa     Zimbabwe  2023-03-21     264391.0        0.0
#
# ...

# %%
#getting information on the dataset
covid_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 297152 entries, 0 to 297151
# Data columns (total 67 columns):
#  #   Column                                      Non-Null Count   Dtype
# ---  ------                                      --------------   -----
#  0   iso_code                                    297152 non-null  object
#  1   continent                                   283021 non-null  object
#  2   location                                    297152 non-null  object
#  3   date                                        297152 non-null  object
#  4   total_cases                                 261401 non-null  float64
#  5   new_cases                                   288675 non-null  float64
#  6   new_cases_smoothed                          287411 non-null  float64
#  7   total_deaths                                240987 non-null  float64
#  8   new_deaths                                  288741 non-null  float64
# ...

# %%
# finding the matrix of the dataset
covid_df.shape
# Out:
# (297152, 67)

# %%
# the first 5 rows 
covid_df.head()
# Out:
#   iso_code continent     location        date  total_cases  new_cases  \
# 0      AFG      Asia  Afghanistan  2020-01-03          NaN        0.0
# 1      AFG      Asia  Afghanistan  2020-01-04          NaN        0.0
# 2      AFG      Asia  Afghanistan  2020-01-05          NaN        0.0
# 3      AFG      Asia  Afghanistan  2020-01-06          NaN        0.0
# 4      AFG      Asia  Afghanistan  2020-01-07          NaN        0.0
#
#    new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  ...  \
# 0                 NaN           NaN         0.0                  NaN  ...
# 1                 NaN           NaN         0.0                  NaN  ...
# 2                 NaN           NaN         0.0                  NaN  ...
# 3                 NaN           NaN         0.0                  NaN  ...
# 4                 NaN           NaN         0.0                  NaN  ...
#
#    male_smokers  handwashing_facilities  hospital_beds_per_thousand  \
# ...

# %%
# the last 5 rows
covid_df.tail()
# Out:
#        iso_code continent  location        date  total_cases  new_cases  \
# 297147      ZWE    Africa  Zimbabwe  2023-03-17     264391.0        0.0
# 297148      ZWE    Africa  Zimbabwe  2023-03-18     264391.0        0.0
# 297149      ZWE    Africa  Zimbabwe  2023-03-19     264391.0        0.0
# 297150      ZWE    Africa  Zimbabwe  2023-03-20     264391.0        0.0
# 297151      ZWE    Africa  Zimbabwe  2023-03-21     264391.0        0.0
#
#         new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  \
# 297147               5.571        5672.0         0.0                  0.0
# 297148               2.714        5672.0         0.0                  0.0
# 297149               0.857        5672.0         0.0                  0.0
# 297150               0.000        5672.0         0.0                  0.0
# 297151               0.000        5672.0         0.0                  0.0
#
#         ...  male_smokers  handwashing_facilities  hospital_beds_per_thousand  \
# ...

# %%
#creating a copy for analysis and testing on
covid_df_copy = covid_df.copy()

# %%
#dorpping columns not relevant to my analysis
covid_df.drop(columns=["new_cases_smoothed",
                        "new_cases_per_million", 
                        "new_cases_smoothed_per_million",
                        "new_deaths_smoothed",
                       "total_cases_per_million",
                       "total_deaths_per_million",
                       "new_deaths_per_million",
                       "icu_patients_per_million",
                       "hosp_patients_per_million",
                       "weekly_icu_admissions_per_million",
                       "weekly_hosp_admissions_per_million",
                       "total_tests_per_thousand",
                       "new_tests_per_thousand",
                       "new_tests_smoothed",
                       "new_tests_smoothed_per_thousand",
                       "new_vaccinations_smoothed",
                       "total_vaccinations_per_hundred",
                       "people_vaccinated_per_hundred",
                       "people_fully_vaccinated_per_hundred",
                       "total_boosters_per_hundred",
                       "new_vaccinations_smoothed_per_million",
                       "new_people_vaccinated_smoothed",
                       "new_people_vaccinated_smoothed_per_hundred",
                      "excess_mortality_cumulative_absolute",
                      "excess_mortality_cumulative",
                      "excess_mortality",
                      "excess_mortality_cumulative_per_million",
                      "hospital_beds_per_thousand"],
             inplace=True);

# %%
covid_df.drop(columns=["new_deaths_smoothed_per_million"], inplace=True)

# %%
covid_df
# Out:
#        iso_code continent     location        date  total_cases  new_cases  \
# 0           AFG      Asia  Afghanistan  2020-01-03          NaN        0.0
# 1           AFG      Asia  Afghanistan  2020-01-04          NaN        0.0
# 2           AFG      Asia  Afghanistan  2020-01-05          NaN        0.0
# 3           AFG      Asia  Afghanistan  2020-01-06          NaN        0.0
# 4           AFG      Asia  Afghanistan  2020-01-07          NaN        0.0
# ...         ...       ...          ...         ...          ...        ...
# 297147      ZWE    Africa     Zimbabwe  2023-03-17     264391.0        0.0
# 297148      ZWE    Africa     Zimbabwe  2023-03-18     264391.0        0.0
# 297149      ZWE    Africa     Zimbabwe  2023-03-19     264391.0        0.0
# 297150      ZWE    Africa     Zimbabwe  2023-03-20     264391.0        0.0
# 297151      ZWE    Africa     Zimbabwe  2023-03-21     264391.0        0.0
#
# ...

# %%
# new dataset after dropping columns
covid_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 297152 entries, 0 to 297151
# Data columns (total 38 columns):
#  #   Column                   Non-Null Count   Dtype
# ---  ------                   --------------   -----
#  0   iso_code                 297152 non-null  object
#  1   continent                283021 non-null  object
#  2   location                 297152 non-null  object
#  3   date                     297152 non-null  object
#  4   total_cases              261401 non-null  float64
#  5   new_cases                288675 non-null  float64
#  6   total_deaths             240987 non-null  float64
#  7   new_deaths               288741 non-null  float64
#  8   reproduction_rate        184817 non-null  float64
#  9   icu_patients             34239 non-null   float64
#  10  hosp_patients            34744 non-null   float64
#  11  weekly_icu_admissions    8961 non-null    float64
#  12  weekly_hosp_admissions   21049 non-null   float64
# ...

# %%
#shape of new data set
covid_df.shape
# Out:
# (297152, 38)

# %%
covid_df.columns
# Out:
# Index(['iso_code', 'continent', 'location', 'date', 'total_cases', 'new_cases',
#        'total_deaths', 'new_deaths', 'reproduction_rate', 'icu_patients',
#        'hosp_patients', 'weekly_icu_admissions', 'weekly_hosp_admissions',
#        'total_tests', 'new_tests', 'positive_rate', 'tests_per_case',
#        'tests_units', 'total_vaccinations', 'people_vaccinated',
#        'people_fully_vaccinated', 'total_boosters', 'new_vaccinations',
#        'stringency_index', 'population_density', 'median_age', 'aged_65_older',
#        'aged_70_older', 'gdp_per_capita', 'extreme_poverty',
#        'cardiovasc_death_rate', 'diabetes_prevalence', 'female_smokers',
#        'male_smokers', 'handwashing_facilities', 'life_expectancy',
#        'human_development_index', 'population'],
#       dtype='object')

# %% [markdown]
# I realised that the column tests_units in an object yet it is supposed to be contain numbers. So the first thing is to check the number of null values to see if we can convert it.

# %%
covid_df.tests_units.isnull()
# Out:
# 0         True
# 1         True
# 2         True
# 3         True
# 4         True
#           ...
# 297147    True
# 297148    True
# 297149    True
# 297150    True
# 297151    True
# Name: tests_units, Length: 297152, dtype: bool

# %% [markdown]
# The test proves the column has all null values. I will proceed to drop the column since it is now irrelevant to my analysis.

# %%
covid_df.drop(columns=["tests_units"], inplace=True)

# %%
covid_df
# Out:
#        iso_code continent     location        date  total_cases  new_cases  \
# 0           AFG      Asia  Afghanistan  2020-01-03          NaN        0.0
# 1           AFG      Asia  Afghanistan  2020-01-04          NaN        0.0
# 2           AFG      Asia  Afghanistan  2020-01-05          NaN        0.0
# 3           AFG      Asia  Afghanistan  2020-01-06          NaN        0.0
# 4           AFG      Asia  Afghanistan  2020-01-07          NaN        0.0
# ...         ...       ...          ...         ...          ...        ...
# 297147      ZWE    Africa     Zimbabwe  2023-03-17     264391.0        0.0
# 297148      ZWE    Africa     Zimbabwe  2023-03-18     264391.0        0.0
# 297149      ZWE    Africa     Zimbabwe  2023-03-19     264391.0        0.0
# 297150      ZWE    Africa     Zimbabwe  2023-03-20     264391.0        0.0
# 297151      ZWE    Africa     Zimbabwe  2023-03-21     264391.0        0.0
#
# ...

# %%
covid_df.to_csv("covid_data_cleaned.csv", index=False)
